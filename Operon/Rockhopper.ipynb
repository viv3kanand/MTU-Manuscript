# %% [markdown]
# # Rockhopper analysis

# %% [markdown]
# ## Set path

# %%
ref = 'ann/mtuTemp/'
fastq = '../data/fastq/'
result1 = 'Results_cond0.1_6'
result2 = 'Results_cond50_6'
result3 = 'Results_cond50_0.1'

# %% [markdown]
# ## Cond_0.1_vs_Cond_6

# %%
# !java -Xmx150G -cp /staging/source/Rockhopper/Rockhopper.jar Rockhopper \
    -p 40 -g $ref -v TRUE -o $result1 -L Cond_0.1,Cond_6 \
    $fastq/4_S4_L001_R1_001.fastq.gz%$fastq/4_S4_L001_R2_001.fastq.gz,\
    $fastq/2_S2_L001_R1_001.fastq.gz%$fastq/2_S2_L001_R2_001.fastq.gz,\
    $fastq/1_S1_L001_R1_001.fastq.gz%$fastq/1_S1_L001_R2_001.fastq.gz \
    $fastq/8_S8_L001_R1_001.fastq.gz%$fastq/8_S8_L001_R2_001.fastq.gz,\
    $fastq/2_S2_L001_R1_001.fastq.gz%$fastq/2_S2_L001_R2_001.fastq.gz
# Out:
# Aligning sequencing reads from files:
# 	4_S4_L001_R1_001.fastq.gz
# 	4_S4_L001_R2_001.fastq.gz
# Total reads:            	3061062
# Successfully aligned reads:	2667646	87%	(>NC_000962.3 Mycobacterium tuberculosis H37Rv, complete genome)
# 	Aligning (sense) to protein-coding genes:	1%
# 	Aligning (antisense) to protein-coding genes:	12%
# 	Aligning (sense) to ribosomal RNAs:	0%
# 	Aligning (antisense) to ribosomal RNAs:	0%
# 	Aligning (sense) to transfer RNAs:	0%
# 	Aligning (antisense) to transfer RNAs:	0%
# 	Aligning (sense) to miscellaneous RNAs:	0%
# 	Aligning (antisense) to miscellaneous RNAs:	84%
# 	Aligning to unannotated regions:        	2%
#
# Aligning sequencing reads from files:
# 	2_S2_L001_R1_001.fastq.gz
# 	2_S2_L001_R2_001.fastq.gz
# Total reads:            	3124230
# Successfully aligned reads:	1876505	60%	(>NC_000962.3 Mycobacterium tuberculosis H37Rv, complete genome)
# 	Aligning (sense) to protein-coding genes:	1%
# ...

# %% [markdown]
# ## Cond_50_vs_cond_6

# %%
# !java -Xmx150G -cp /staging/source/Rockhopper/Rockhopper.jar Rockhopper \
    -p 40 -g $ref -v TRUE -o $result2 -L Cond_50,Cond_6 \
    $fastq/9_S9_L001_R1_001.fastq.gz%$fastq/9_S9_L001_R2_001.fastq.gz,\
    $fastq/6_S6_L001_R1_001.fastq.gz%$fastq/6_S6_L001_R2_001.fastq.gz,\
    $fastq/3_S3_L001_R1_001.fastq.gz%$fastq/3_S3_L001_R2_001.fastq.gz \
    $fastq/8_S8_L001_R1_001.fastq.gz%$fastq/8_S8_L001_R2_001.fastq.gz,\
    $fastq/2_S2_L001_R1_001.fastq.gz%$fastq/2_S2_L001_R2_001.fastq.gz
# Out:
# Aligning sequencing reads from files:
# 	9_S9_L001_R1_001.fastq.gz
# 	9_S9_L001_R2_001.fastq.gz
# Total reads:            	2396948
# Successfully aligned reads:	1667804	70%	(>NC_000962.3 Mycobacterium tuberculosis H37Rv, complete genome)
# 	Aligning (sense) to protein-coding genes:	2%
# 	Aligning (antisense) to protein-coding genes:	19%
# 	Aligning (sense) to ribosomal RNAs:	0%
# 	Aligning (antisense) to ribosomal RNAs:	0%
# 	Aligning (sense) to transfer RNAs:	0%
# 	Aligning (antisense) to transfer RNAs:	0%
# 	Aligning (sense) to miscellaneous RNAs:	0%
# 	Aligning (antisense) to miscellaneous RNAs:	76%
# 	Aligning to unannotated regions:        	2%
#
# Aligning sequencing reads from files:
# 	6_S6_L001_R1_001.fastq.gz
# 	6_S6_L001_R2_001.fastq.gz
# Total reads:            	2786683
# Successfully aligned reads:	2447506	88%	(>NC_000962.3 Mycobacterium tuberculosis H37Rv, complete genome)
# 	Aligning (sense) to protein-coding genes:	2%
# ...

# %% [markdown]
# ## Cond_50_vs_Cond_0.1

# %%
# !java -Xmx150G -cp /staging/source/Rockhopper/Rockhopper.jar Rockhopper \
    -p 40 -g $ref -v TRUE -o $result3 -L Cond_50,Cond_0.1 \
    $fastq/9_S9_L001_R1_001.fastq.gz%$fastq/9_S9_L001_R2_001.fastq.gz,\
    $fastq/6_S6_L001_R1_001.fastq.gz%$fastq/6_S6_L001_R2_001.fastq.gz,\
    $fastq/3_S3_L001_R1_001.fastq.gz%$fastq/3_S3_L001_R2_001.fastq.gz \
    $fastq/4_S4_L001_R1_001.fastq.gz%$fastq/4_S4_L001_R2_001.fastq.gz,\
    $fastq/2_S2_L001_R1_001.fastq.gz%$fastq/2_S2_L001_R2_001.fastq.gz,\
    $fastq/1_S1_L001_R1_001.fastq.gz%$fastq/1_S1_L001_R2_001.fastq.gz
# Out:
# Aligning sequencing reads from files:
# 	9_S9_L001_R1_001.fastq.gz
# 	9_S9_L001_R2_001.fastq.gz
# Total reads:            	2396948
# Successfully aligned reads:	1667804	70%	(>NC_000962.3 Mycobacterium tuberculosis H37Rv, complete genome)
# 	Aligning (sense) to protein-coding genes:	2%
# 	Aligning (antisense) to protein-coding genes:	19%
# 	Aligning (sense) to ribosomal RNAs:	0%
# 	Aligning (antisense) to ribosomal RNAs:	0%
# 	Aligning (sense) to transfer RNAs:	0%
# 	Aligning (antisense) to transfer RNAs:	0%
# 	Aligning (sense) to miscellaneous RNAs:	0%
# 	Aligning (antisense) to miscellaneous RNAs:	76%
# 	Aligning to unannotated regions:        	2%
#
# Aligning sequencing reads from files:
# 	6_S6_L001_R1_001.fastq.gz
# 	6_S6_L001_R2_001.fastq.gz
# Total reads:            	2786683
# Successfully aligned reads:	2447506	88%	(>NC_000962.3 Mycobacterium tuberculosis H37Rv, complete genome)
# 	Aligning (sense) to protein-coding genes:	2%
# ...
